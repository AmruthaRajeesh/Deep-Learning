# %% [markdown]
# **Yahoo-stock data**

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Dataset/yahooStock.csv")
df
# Out:
#      symbol                 symbolName                fullName  \
# 0      OSIS          O S I Systems Inc       Paul Keith Morben
# 1      OSIS          O S I Systems Inc         James B Hawkins
# 2        UP   Wheels Up Experience Inc  Meaghan Danielle Wells
# 3        UP   Wheels Up Experience Inc             Mark Briffa
# 4      EWBC          East West Bancorp          Molly Campbell
# ...     ...                        ...                     ...
# 1295   COCO  The Vita Coco Company Inc          Martin F Roper
# 1296    APP         Applovin Corp Cl A          Dmitriy Dorosh
# 1297   COCO  The Vita Coco Company Inc          Michael Kirban
# 1298   CNXC            Concentrix Corp  Christopher A Caldwell
# 1299   CNXC            Concentrix Corp         Cormac J Twomey
#
#        shortJobTitle transactionType  amount  reportedPrice  usdValue  \
# 0              Pres.            Sell     416       279.1000    116105
# ...

# %%
df.isnull().sum()
# Out:
# symbol               0
# symbolName           0
# fullName             0
# shortJobTitle      535
# transactionType      0
# amount               0
# reportedPrice        0
# usdValue             0
# eodHolding           0
# transactionDate      0
# symbolCode           0
# hasOptions           0
# symbolType           0
# dtype: int64

# %%
df.drop(['symbol'],axis=1,inplace=True)

# %%
df["shortJobTitle"].fillna(df["shortJobTitle"].mode()[0],inplace=True)
df
# Out:
# /tmp/ipython-input-2302559170.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["shortJobTitle"].fillna(df["shortJobTitle"].mode()[0],inplace=True)
#                      symbolName                fullName   shortJobTitle  \
# 0             O S I Systems Inc       Paul Keith Morben           Pres.
# 1             O S I Systems Inc         James B Hawkins             CEO
# 2      Wheels Up Experience Inc  Meaghan Danielle Wells   Chf Dev. Off.
# ...

# %%
df.isnull().sum()
# Out:
# symbolName         0
# fullName           0
# shortJobTitle      0
# transactionType    0
# amount             0
# reportedPrice      0
# usdValue           0
# eodHolding         0
# transactionDate    0
# symbolCode         0
# hasOptions         0
# symbolType         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1300, 12)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['symbolName'] = le.fit_transform(df['symbolName'])
df['fullName'] = le.fit_transform(df['fullName'])
df['shortJobTitle'] = le.fit_transform(df['shortJobTitle'])
df['transactionType'] = le.fit_transform(df['transactionType'])
df['symbolCode'] = le.fit_transform(df['symbolCode'])
df['hasOptions'] = le.fit_transform(df['hasOptions'])

# %%
df['transactionDate'] = pd.to_datetime(df['transactionDate'])
df['day'] = df['transactionDate'].dt.day
df['month'] = df['transactionDate'].dt.month
df['year'] = df['transactionDate'].dt.year

# %%
df.drop(['transactionDate','year'],axis=1,inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = df.corr()
sns.heatmap(corr_matrix,annot=True,fmt='0.01f',cmap='coolwarm')

plt.title('Correlation Matrix')
plt.show()

# %%
df.drop(['amount','symbolType','day'],axis=1,inplace=True)

# %%
transactionType_corr = df.corr()["transactionType"]
transactionType_corr = transactionType_corr.drop('transactionType')
sns.heatmap(transactionType_corr.to_frame(),annot=True,fmt='.02f',cmap='coolwarm')

plt.title('Correlation between transactionType and other features')
plt.show()

# %%
df.drop(['symbolName','hasOptions','shortJobTitle','month'],axis=1,inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col==exclude_column:
      continue

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3-Q1

    lower_bound = Q1-1.5*IQR
    upper_bound = Q3+1.5*IQR

    df = df[(df[col]>=lower_bound) & (df[col]<=upper_bound)]
  return df

df_cleaned = remove_outliers_iqr(df,exclude_column='transactionType')
df=df_cleaned

# %%
x = df[['fullName','reportedPrice','usdValue','eodHolding','symbolCode']]
y = df['transactionType']

# %%
from sklearn.preprocessing import StandardScaler

scaler  =StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train ,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# %%
model = Sequential([Dense(64,input_shape=(5,),activation='relu'),
                    Dense(32,activation='relu'),
                    Dense(3, activation='softmax')])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=[SparseCategoricalAccuracy()])

# %%
model.fit(x_train,y_train,epochs=1000)
# Out:
# Epoch 1/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9053 - sparse_categorical_accuracy: 0.6313
# Epoch 2/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9114 - sparse_categorical_accuracy: 0.6213
# Epoch 3/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9136 - sparse_categorical_accuracy: 0.6236
# Epoch 4/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8925 - sparse_categorical_accuracy: 0.6159
# Epoch 5/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8922 - sparse_categorical_accuracy: 0.6194
# Epoch 6/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9278 - sparse_categorical_accuracy: 0.5976
# Epoch 7/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8952 - sparse_categorical_accuracy: 0.6165
# Epoch 8/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8798 - sparse_categorical_accuracy: 0.6393
# Epoch 9/900
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8722 - sparse_categorical_accuracy: 0.6217
# Epoch 10/900
# ...

# %%
test_loss ,test_acc = model.evaluate(x_test,y_test)
print(f'\nTest Accuracy: {test_acc}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 63.2323 - sparse_categorical_accuracy: 0.7276
#
# Test Accuracy: 0.7244898080825806
